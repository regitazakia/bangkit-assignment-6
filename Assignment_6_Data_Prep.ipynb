# %% [markdown]
# <a href="https://colab.research.google.com/github/regitazakia/bangkit-assignment-6/blob/master/Assignment_6_Data_Prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# Import statements required for Plotly 
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls

print(tf.__version__)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 2.2.0-rc3

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d8ae545-9111-412e-a646-58c69e93aba9" name="files[]" multiple disabled />
#      <output id="result-3d8ae545-9111-412e-a646-58c69e93aba9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ibm-data.csv to ibm-data (1).csv

# %%
import pandas as pd
import io
data = pd.read_csv(io.BytesIO(uploaded['ibm-data.csv']))

# %%
data.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
data.describe()
# Out:
#                Age    DailyRate  ...  YearsSinceLastPromotion  YearsWithCurrManager
# count  1470.000000  1470.000000  ...              1470.000000           1470.000000
# mean     36.923810   802.485714  ...                 2.187755              4.123129
# std       9.135373   403.509100  ...                 3.222430              3.568136
# min      18.000000   102.000000  ...                 0.000000              0.000000
# 25%      30.000000   465.000000  ...                 0.000000              2.000000
# 50%      36.000000   802.000000  ...                 1.000000              3.000000
# 75%      43.000000  1157.000000  ...                 3.000000              7.000000
# max      60.000000  1499.000000  ...                15.000000             17.000000
#
# [8 rows x 26 columns]

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# *Data Preparation*

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# Create a label encoder object
le = LabelEncoder()

# %%
# Label Encoding will be used for columns with 2 or less unique values
le_count = 0
for col in data.columns[1:]:
    if data[col].dtype == 'object':
        if len(list(data[col].unique())) <= 2:
            le.fit(data[col])
            data[col] = le.transform(data[col])
            le_count += 1
print('{} columns were label encoded.'.format(le_count))
# Out:
# 4 columns were label encoded.

# %%
# convert rest of categorical variable into dummy
data = pd.get_dummies(data, drop_first=True)

# %%
print(data.shape)
data.head()
# Out:
# (1470, 49)
#    Age  Attrition  ...  MaritalStatus_Married  MaritalStatus_Single
# 0   41          1  ...                      0                     1
# 1   49          0  ...                      1                     0
# 2   37          1  ...                      0                     1
# 3   33          0  ...                      1                     0
# 4   27          0  ...                      1                     0
#
# [5 rows x 49 columns]

# %%
# import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 5))
HR_col = list(data.columns)
HR_col.remove('Attrition')
for col in HR_col:
    data[col] = data[col].astype(float)
    data[[col]] = scaler.fit_transform(data[[col]])
data['Attrition'] = pd.to_numeric(data['Attrition'], downcast='float')
data.head()
# Out:
#         Age  Attrition  ...  MaritalStatus_Married  MaritalStatus_Single
# 0  2.738095        1.0  ...                    0.0                   5.0
# 1  3.690476        0.0  ...                    5.0                   0.0
# 2  2.261905        1.0  ...                    0.0                   5.0
# 3  1.785714        0.0  ...                    5.0                   0.0
# 4  1.071429        0.0  ...                    5.0                   0.0
#
# [5 rows x 49 columns]

# %% [markdown]
# *Data Visualization*

# %%
# Plotting the scatter plots
f, axes = plt.subplots(3, 3, figsize=(10, 8), 
                       sharex=False, sharey=False)
s = np.linspace(0, 3, 10)
cmap = sns.cubehelix_palette(start=0.0, light=1, as_cmap=True)

#Daily Rate vs DistanceFromHome
x = data['DailyRate'].values
y = data['DistanceFromHome'].values
sns.scatterplot(x, y, ax=axes[1,0])
axes[1,0].set( title = 'Daily Rate vs DistancefromHome')

#Years at company VS DailyRate
x = data['YearsAtCompany'].values
y = data['DailyRate'].values
sns.scatterplot(x, y, ax=axes[2,0])
axes[2,0].set( title = 'Years at company vs Daily Rate')

#WorklifeBalance VS Satisfaction
x = data['WorkLifeBalance'].values
y = data['JobSatisfaction'].values
sns.scatterplot(x, y, ax=axes[2,2])
axes[2,2].set( title = 'WorklifeBalance vs Satisfaction')

#Age VS TotalWorkingYears
x = data['Age'].values
y = data['TotalWorkingYears'].values
sns.scatterplot(x, y, ax=axes[0,0])
axes[0,0].set( title = 'Age vs Total working years')

# Age VS DailyRate
cmap = sns.cubehelix_palette(start=0.333333333333, light=1, as_cmap=True)
# Generate and plot
x = data['Age'].values
y = data['DailyRate'].values
sns.scatterplot(x, y, ax=axes[0,1])
axes[0,1].set( title = 'Age vs Daily Rate')

# YearsinCurrentRole VS Satisfaction
# Generate and plot
x = data['YearsAtCompany'].values
y = data['Age'].values
sns.scatterplot(x, y, ax=axes[1,2])
axes[1,2].set( title = 'Years at Company vs Age')

f.tight_layout()
